# %%
import requests
from requests_html import HTMLSession
import pandas as pd
import numpy as np
import re
from bs4 import BeautifulSoup
from rich import print

# %%
url = 'https://www.simplyhired.com/search?q=Dentist+Jobs&l='
base_url = 'https://www.simplyhired.com'

# %%
session = HTMLSession()
html = session.get(url)
content = html.text

# %%
soup = BeautifulSoup(content, 'html.parser')

# %%
job_cards = soup.find_all('div', class_ = 'css-f8dtpc')

# %%
job1 = job_cards[:2]

# %%
print(job1)
# Out:
# [
#     <div class="css-f8dtpc" data-jobkey="E6HwW0dmT81FAXDmMbuSBYcZzELff00mqOC59Jt8sbPwN_PO1p0Kiw"
# data-testid="searchSerpJob" role="presentation"><div class="chakra-stack css-1igwmid"><h2 class="chakra-text
# css-8rdtm5" data-testid="searchSerpJobTitle"><a class="chakra-button css-1djbb1k"
# data-mdref="/job/E6HwW0dmT81FAXDmMbuSBYcZzELff00mqOC59Jt8sbPwN_PO1p0Kiw?jobCardTrackingKey=5-yul1-0-1hs45d2olje1580
# 0-6088909d09fe5a66&amp;xkcb=SoCP67M3BEC7geRJqB0ObzkdCdPP"
# href="/job/E6HwW0dmT81FAXDmMbuSBYcZzELff00mqOC59Jt8sbPwN_PO1p0Kiw" tabindex="0">Associate Dentist</a></h2></div><p
# class="chakra-text css-1sawo7p"><span class="css-lvyu5j"><span data-testid="companyName">Portland Dental
# Practice</span> —</span><span class="css-1t92pv" data-testid="searchSerpJobLocation">Portland, ME</span><style
# data-emotion="css epvm6">.css-epvm6{white-space:nowrap;}</style><span aria-label="2.6 out of 5 stars"
# class="css-epvm6" data-testid="searchSerpJobCompanyRating" role="img"><span aria-hidden="true"
# class="css-0">2.6<!-- --> </span><style data-emotion="css
# c4tn3a">.css-c4tn3a{height:16px;color:var(--chakra-colors-yellow-500);max-width:12px;display:inline-block;}</style>
# <svg aria-hidden="true" class="svg-inline--fa fa-star css-c4tn3a" data-icon="star" data-prefix="fas"
# focusable="false" role="img" viewbox="0 0 576 512" xmlns="http://www.w3.org/2000/svg"><path d="M316.9 18C311.6 7
# 300.4 0 288.1 0s-23.4 7-28.8 18L195 150.3 51.4 171.5c-12 1.8-22 10.2-25.7 21.7s-.7 24.2 7.9 32.7L137.8 329 113.2
# 474.7c-2 12 3 24.2 12.9 31.3s23 8 33.8 2.3l128.3-68.5 128.3 68.5c10.8 5.7 23.9 4.9 33.8-2.3s14.9-19.3
# 12.9-31.3L438.5 329 542.7 225.9c8.6-8.5 11.7-21.2 7.9-32.7s-13.7-19.9-25.7-21.7L381.2 150.3 316.9 18z"
# fill="currentColor"></path></svg></span></p><p class="chakra-text css-jhqp7z"
# data-testid="searchSerpJobSnippet">Our state of the art facility allows optimal patient care, a comprehensive
# approach to full service dentistry along with a strong focus on quality, service and…</p><div class="css-2imjyh"><p
# class="chakra-text css-1g1y608" data-testid="searchSerpJobSalaryConfirmed">$600 - $800 a day</p><p
# class="chakra-text css-u40boz" data-testid="searchSerpJobQuickApply">Quick Apply</p><div
# class="css-17xejub"></div></div></div>,
#     <div class="css-f8dtpc" data-jobkey="XiGghkup8AkFi4FR1GEYRa0qnXWZO_9FC1XZn3QqcUV00wM5X9bMLw"
# data-testid="searchSerpJob" role="presentation"><div class="chakra-stack css-1igwmid"><h2 class="chakra-text
# css-8rdtm5" data-testid="searchSerpJobTitle"><a class="chakra-button css-1djbb1k"
# data-mdref="/job/XiGghkup8AkFi4FR1GEYRa0qnXWZO_9FC1XZn3QqcUV00wM5X9bMLw?jobCardTrackingKey=5-yul1-0-1hs45d2olje1580
# 0-1a0fa37771e2f6ff&amp;xkcb=SoDZ67M3BEC7gexJqB0KbzkdCdPP"
# href="/job/XiGghkup8AkFi4FR1GEYRa0qnXWZO_9FC1XZn3QqcUV00wM5X9bMLw" tabindex="0">General Dentist
# -Waukesha</a></h2></div><p class="chakra-text css-1sawo7p"><span class="css-lvyu5j"><span
# data-testid="companyName">Dental 360 &amp; Associates</span> —</span><span class="css-1t92pv"
# data-testid="searchSerpJobLocation">Waukesha, WI</span></p><p class="chakra-text css-jhqp7z"
# data-testid="searchSerpJobSnippet">Come join our Dental 360 team, we are looking for a General Dentist with
# motivation, skills, and passion to provide comprehensive dentistry in Chicago &amp;…</p><div class="css-2imjyh"><p
# class="chakra-text css-1g1y608" data-testid="searchSerpJobSalaryConfirmed">$1,000 a day</p><p class="chakra-text
# css-u40boz" data-testid="searchSerpJobQuickApply">Quick Apply</p><div class="css-17xejub"></div><p
# class="chakra-text css-5yilgw" data-testid="searchSerpJobDateStamp">14d</p></div></div>
# ]

# %%
def extract_job_details(job_card):
  """
  Extracts key features (title, company, location, salary, snippet, date, job URL) from a job listing HTML snippet.

  Args:
      html_content: The HTML content of the job listing snippet.

  Returns:
      A dictionary containing extracted key features of the job.
  """

 

    # Extract job title using data-testid
  job_title_element = soup.find('a', class_="chakra-button")
  job_title = job_title_element.text.strip() if job_title_element else None

  # Extract company name using data-testid
  company_element = soup.find('span', data_testid='companyName')
  company_name = company_element.text.strip() if company_element else None


  # Extract location
  location_element = job_card.find('span', data_testid='searchSerpJobLocation')
  location = location_element.text.strip() if location_element else None

  # Extract salary
  salary_element = job_card.find('p', class_='chakra-text css-1g1y608')
  salary = salary_element.text.strip() if salary_element else None

  # Extract job snippet
  snippet_element = job_card.find('p', class_='chakra-text css-jhqp7z')
  snippet = snippet_element.text.strip() if snippet_element else None

  # Extract date posted
  date_element = job_card.find('p', class_='chakra-text css-5yilgw')
  date_posted = date_element.text.strip() if date_element else None

  # Extract job URL
  job_url_element = job_card.find('h2', class_='chakra-text css-8rdtm5').find('a')
  job_url = (base_url+job_url_element['href']) if job_url_element else None

  # Create a dictionary with extracted features
  job_details = {
      'title': job_title,
      'company': company_name,
      'location': location,
      'salary': salary,
      'snippet': snippet,
      'date_posted': date_posted,
      'job_url': job_url
  }

  return job_details

# %%
overall = [extract_job_details(i) for i in job_cards]

# %%
print(overall)
# Out:
# [
#     {
#         'title': 'General Dentist',
#         'company': None,
#         'location': None,
#         'salary': '$600 - $800 a day',
#         'snippet': 'Our state of the art facility allows optimal patient care, a comprehensive approach to full
# service dentistry along with a strong focus on quality, service and…',
#         'date_posted': None,
#         'job_url': 'https://www.simplyhired.com/job/E6HwW0dmT81FAXDmMbuSBYcZzELff00mqOC59Jt8sbPwN_PO1p0Kiw'
#     },
#     {
#         'title': 'General Dentist',
#         'company': None,
#         'location': None,
#         'salary': '$1,000 a day',
#         'snippet': 'Come join our Dental 360 team, we are looking for a General Dentist with motivation, skills,
# and passion to provide comprehensive dentistry in Chicago &…',
#         'date_posted': '14d',
#         'job_url': 'https://www.simplyhired.com/job/XiGghkup8AkFi4FR1GEYRa0qnXWZO_9FC1XZn3QqcUV00wM5X9bMLw'
#     },
#     {
#         'title': 'General Dentist',
#         'company': None,
#         'location': None,
#         'salary': '$138,215 - $343,695 a year',
#         'snippet': 'All phases of dentistry includes: crown and bridge, molar endodontics, cosmetics, oral surgery
# including molar impactions, periodontics including minor crown…',
#         'date_posted': None,
#         'job_url': 'https://www.simplyhired.com/job/cIsVj3t8bW9jOyVwM9CLvYEW1k712GvZDu6gl96PZltEHNjxYuN7pw'
#     },
#     {
#         'title': 'General Dentist',
#         'company': None,
#         'location': None,
#         'salary': '$750 - $900 a day',
#         'snippet': 'Adhere to all federal and government regulations, including the state dental board rules and
# regulations, HIPPA and OSHA regulations.',
#         'date_posted': '10d',
#         'job_url': 'https://www.simplyhired.com/job/VWK8GkLfirgiKGQrAl6U4YIXF0Rvwg6i0Lns1_TiG6Se3-hMBbQnvQ'
#     },
#     {
#         'title': 'General Dentist',
#         'company': None,
#         'location': None,
#         'salary': '$73,061 - $302,166 a year',
#         'snippet': 'Looking for a general dentist associate for a friendly dental office. Will perform all aspects
# of dentistry. Job Types: Full-time, Part-time, Contract.',
#         'date_posted': '9h',
#         'job_url': 'https://www.simplyhired.com/job/6drjVceN9ooqjdlGscNEy_T2qrbHxa2mjgPE25p0fYK75eIuMOkFWg'
#     },
#     {
#         'title': 'General Dentist',
#         'company': None,
#         'location': None,
#         'salary': '$500 a day',
#         'snippet': 'As a Remote Dentist, you will conduct virtual oral health assessments for patients and adhere
# to Medi-Cal clinical guidelines for Synchronize Tele-dentistry.',
#         'date_posted': '5d',
#         'job_url': 'https://www.simplyhired.com/job/WHuv35wzqVVXlt3BbUc3l_0N7CuXJPPcZgXIIkZup4P8CYFrIso0lQ'
#     },
#     {
#         'title': 'General Dentist',
#         'company': None,
#         'location': None,
#         'salary': '$800 - $1,500 a day',
#         'snippet': 'Highly organized busy group practice is seeking a qualified dentist with a minimum of 2 years
# experience for full or part time. Job Types: Full-time, Part-time.',
#         'date_posted': '7d',
#         'job_url': 'https://www.simplyhired.com/job/_ajAwCKufSsPaRhLjMD7me9dTGcOWH2dSQbmxXPZ-nkaEE4pQPkn8w'
#     },
#     {
#         'title': 'General Dentist',
#         'company': None,
#         'location': None,
#         'salary': 'From $750 a day',
#         'snippet': 'Current license to practice dentistry in the state of NJ. Supervise the work of professional,
# technical and administrative staff.',
#         'date_posted': '3d',
#         'job_url': 'https://www.simplyhired.com/job/ERJebioOTX1jBC8j3cLTZyYqHrkIizFJkLCPW-SNcWWwbCz1zp4rKg'
#     },
#     {
#         'title': 'General Dentist',
#         'company': None,
#         'location': None,
#         'salary': '$700 - $950 a day',
#         'snippet': 'We are a private, expanding dental office providing a full-range of high quality, comprehensive
# care.',
#         'date_posted': '14d',
#         'job_url': 'https://www.simplyhired.com/job/6slGepMiIU-gIDkixXZdMxop9NhtuNoNNkT9e_zlxrQGoF6ZjYnAnw'
#     },
#     {
#         'title': 'General Dentist',
#         'company': None,
#         'location': None,
#         'salary': '$150,000 - $200,000 a year',
#         'snippet': 'Carry out agreed clinical treatments. Keep abreast of new developments in dentistry through
# structured continuing professional developments.',
#         'date_posted': None,
#         'job_url': 'https://www.simplyhired.com/job/_jXSKmib9-VnhxwMtkr2Ss87pvqAZZ65ODb0HDwHuBlVDbTbHEl6cQ'
#     },
#     {
#         'title': 'General Dentist',
#         'company': None,
#         'location': None,
#         'salary': 'Up to $4,000 a day',
#         'snippet': 'We are seeking a bilingual( english and spanish) compassionate and highly skilled dentist with
# ample experience in placing and restoring dental implants…',
#         'date_posted': '1d',
#         'job_url': 'https://www.simplyhired.com/job/9AKn1kLGqOMetKeE-gP1m7ODp9aMbANKjfjXlNGGShacI1AEXP7JiQ'
#     },
#     {
#         'title': 'General Dentist',
#         'company': None,
#         'location': None,
#         'salary': '$155,699 - $221,590 a year',
#         'snippet': 'General Dentist Needed for Private Practice in South Orange. We are multispecialty group. We
# have a great team and great patients. If you like helping people,…',
#         'date_posted': '5d',
#         'job_url': 'https://www.simplyhired.com/job/4ri65Egtt9SOV8PTj33hksPr3lDXoZaGEe1YIl4GLMTYMuSRapT9kw'
#     },
#     {
#         'title': 'General Dentist',
#         'company': None,
#         'location': None,
#         'salary': '$500 - $2,000 a day',
#         'snippet': 'The position is full-time for the right candidate. Experience is preferred (at least 1 year),
# but we are happy to mentor as needed.',
#         'date_posted': None,
#         'job_url': 'https://www.simplyhired.com/job/pQPxKpz1LnIiTov7EPhzDhlNY1IcAb1dVCm3UiQcUOGNJc7_uBR8zA'
#     },
#     {
#         'title': 'General Dentist',
#         'company': None,
#         'location': None,
#         'salary': '$20 - $23 an hour',
#         'snippet': 'Current RDA certification and compliance with state dental board regulations. Strong
# organizational and multitasking skills to handle a busy front desk.',
#         'date_posted': '18h',
#         'job_url': 'https://www.simplyhired.com/job/c3had8QKSJfAjHglmqZrz6IL1ZZo0dFdwZynJlqiutrlzupa-vH8kw'
#     },
#     {
#         'title': 'General Dentist',
#         'company': None,
#         'location': None,
#         'salary': '$800 - $2,000 a day',
#         'snippet': 'Office is busy with high production. Recommended for Associate to be comfortable with treatment
# planning , most Root Canals, and extractions.',
#         'date_posted': None,
#         'job_url': 'https://www.simplyhired.com/job/AX5-Z2G8juvyI-chRbO-f82KBsnYx_6W_Z6E924BnlZVK7BPSOookg'
#     },
#     {
#         'title': 'General Dentist',
#         'company': None,
#         'location': None,
#         'salary': '$1,200 - $1,800 a day',
#         'snippet': 'The position can be both part-time or full-time. Job Types: Full-time, Part-time.',
#         'date_posted': '12d',
#         'job_url': 'https://www.simplyhired.com/job/syXL2pSVgfwHkJjto5j0KH-MluD_Kpt3maOyel4sODteXCW4zaVZWQ'
#     },
#     {
#         'title': 'General Dentist',
#         'company': None,
#         'location': None,
#         'salary': '$700 - $1,500 a day',
#         'snippet': 'As an associate, you will examine, diagnose, and provide treatment and counseling to patients
# in a comprehensive manner.',
#         'date_posted': '3d',
#         'job_url': 'https://www.simplyhired.com/job/UsKTD7Qcvmo2kVFUNwkES9gthM8x8uq8J9uuxhiIMLY6a8mhvRYQMA'
#     },
#     {
#         'title': 'General Dentist',
#         'company': None,
#         'location': None,
#         'salary': '$120,000 - $250,000 a year',
#         'snippet': 'You may be the candidate we need if you have experience in advanced full mouth rehabilitation
# with crown and bridge and total mouth implant cases and hybrids.',
#         'date_posted': None,
#         'job_url': 'https://www.simplyhired.com/job/v5h3PWY_6VFScJeAxFWhMhWQWZiUizOBUvLar8vqvMyZPopaXtf6mA'
#     },
#     {
#         'title': 'General Dentist',
#         'company': None,
#         'location': None,
#         'salary': '$800 - $2,000 a day',
#         'snippet': 'Looking For General Dentist who is comfortable with seeing Pediatric patients. Job Types:
# Full-time, Part-time.',
#         'date_posted': None,
#         'job_url': 'https://www.simplyhired.com/job/zxj5yq2fkiqdJ7JgsWfm5Dm3nPJxDNAlyZgUDtOlta14WP9meTREsw'
#     }
# ]

# %%
https://www.simplyhired.com/job/E6HwW0dmT81FAXDmMbuSBYcZzELff00mqOC59Jt8sbPwN_PO1p0Kiw
