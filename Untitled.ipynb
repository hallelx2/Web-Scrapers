# %%
import requests
from requests_html import HTMLSession
import pandas as pd
import numpy as np
import re
from bs4 import BeautifulSoup
from rich import print

# %%
url = 'https://www.simplyhired.com/search?q=Dentist+Jobs&l='

# %%
session = HTMLSession()
html = session.get(url)
content = html.text

# %%
soup = BeautifulSoup(content, 'html.parser')

# %%
job_cards = soup.find_all('div', class_ = 'css-f8dtpc')

# %%
job1 = job_cards[:2]

# %%
print(job1)
# Out:
# [
#     <div class="css-f8dtpc" data-jobkey="XiGghkup8AkFi4FR1GEYRa0qnXWZO_9FC1XZn3QqcUV00wM5X9bMLw"
# data-testid="searchSerpJob" role="presentation"><div class="chakra-stack css-1igwmid"><h2 class="chakra-text
# css-8rdtm5" data-testid="searchSerpJobTitle"><a class="chakra-button css-1djbb1k"
# data-mdref="/job/XiGghkup8AkFi4FR1GEYRa0qnXWZO_9FC1XZn3QqcUV00wM5X9bMLw?jobCardTrackingKey=5-yul1-0-1hs42vvgejkut80
# 3-1a0fa37771e2f6ff&amp;xkcb=SoA-67M3BENwKbx8VB0ObzkdCdPP"
# href="/job/XiGghkup8AkFi4FR1GEYRa0qnXWZO_9FC1XZn3QqcUV00wM5X9bMLw" tabindex="0">General Dentist
# -Waukesha</a></h2></div><p class="chakra-text css-1sawo7p"><span class="css-lvyu5j"><span
# data-testid="companyName">Dental 360 &amp; Associates</span> —</span><span class="css-1t92pv"
# data-testid="searchSerpJobLocation">Waukesha, WI</span></p><p class="chakra-text css-jhqp7z"
# data-testid="searchSerpJobSnippet">Come join our Dental 360 team, we are looking for a General Dentist with
# motivation, skills, and passion to provide comprehensive dentistry in Chicago &amp;…</p><div class="css-2imjyh"><p
# class="chakra-text css-1g1y608" data-testid="searchSerpJobSalaryConfirmed">$1,000 a day</p><p class="chakra-text
# css-u40boz" data-testid="searchSerpJobQuickApply">Quick Apply</p><div class="css-17xejub"></div><style
# data-emotion="css
# 5yilgw">.css-5yilgw{font-size:var(--chakra-fontSizes-sm);font-weight:var(--chakra-fontWeights-normal);line-height:v
# ar(--chakra-lineHeights-base);margin-left:auto;}</style><p class="chakra-text css-5yilgw"
# data-testid="searchSerpJobDateStamp">14d</p></div></div>,
#     <div class="css-f8dtpc" data-jobkey="dfAg_JB-CuHubrpqv_z11RMSazfZtpwS8ZKH8uU2EVqJNYzh9h_cjw"
# data-testid="searchSerpJob" role="presentation"><div class="chakra-stack css-1igwmid"><h2 class="chakra-text
# css-8rdtm5" data-testid="searchSerpJobTitle"><a class="chakra-button css-1djbb1k"
# data-mdref="/job/dfAg_JB-CuHubrpqv_z11RMSazfZtpwS8ZKH8uU2EVqJNYzh9h_cjw?jobCardTrackingKey=5-yul1-0-1hs42vvgejkut80
# 3-769d1b2732dd9e44&amp;xkcb=SoCj67M3BENwKaR8VB0KbzkdCdPP"
# href="/job/dfAg_JB-CuHubrpqv_z11RMSazfZtpwS8ZKH8uU2EVqJNYzh9h_cjw" tabindex="0">General Dentist</a></h2></div><p
# class="chakra-text css-1sawo7p"><span class="css-lvyu5j"><span data-testid="companyName">Maine Dental
# Boutique</span> —</span><span class="css-1t92pv" data-testid="searchSerpJobLocation">Winthrop, ME</span></p><p
# class="chakra-text css-jhqp7z" data-testid="searchSerpJobSnippet">Must be licensed in the State of Maine to
# practice Dentistry. Job Types: Part-time, Contract, Temporary.</p><div class="css-2imjyh"><p class="chakra-text
# css-1g1y608" data-testid="searchSerpJobSalaryConfirmed">From $90 an hour</p><p class="chakra-text css-u40boz"
# data-testid="searchSerpJobQuickApply">Quick Apply</p><div class="css-17xejub"></div><p class="chakra-text
# css-5yilgw" data-testid="searchSerpJobDateStamp">5h</p></div></div>
# ]

# %%
def extract_job_details(job_card):
  """
  Extracts key features (title, company, location, salary, snippet, date, job URL) from a job listing HTML snippet.

  Args:
      html_content: The HTML content of the job listing snippet.

  Returns:
      A dictionary containing extracted key features of the job.
  """

 

    # Extract job title using data-testid
  job_title_element = soup.find('a', class_="chakra-button css-1djbb1k")
  job_title = job_title_element.text.strip() if job_title_element else None

  # Extract company name using data-testid
  company_element = soup.find('span', data_testid='companyName')
  company_name = company_element.text.strip() if company_element else None


  # Extract location
  location_element = job_card.find('span', data_testid='searchSerpJobLocation')
  location = location_element.text.strip() if location_element else None

  # Extract salary
  salary_element = job_card.find('p', class_='chakra-text css-1g1y608')
  salary = salary_element.text.strip() if salary_element else None

  # Extract job snippet
  snippet_element = job_card.find('p', class_='chakra-text css-jhqp7z')
  snippet = snippet_element.text.strip() if snippet_element else None

  # Extract date posted
  date_element = job_card.find('p', class_='chakra-text css-5yilgw')
  date_posted = date_element.text.strip() if date_element else None

  # Extract job URL
  job_url_element = job_card.find('h2', class_='chakra-text css-8rdtm5').find('a')
  job_url = job_url_element['href'] if job_url_element else None

  # Create a dictionary with extracted features
  job_details = {
      'title': job_title,
      'company': company_name,
      'location': location,
      'salary': salary,
      'snippet': snippet,
      'date_posted': date_posted,
      'job_url': job_url
  }

  return job_details

# %%
overall = [extract_job_details(i) for i in job_cards]

# %%
print(overall)
# Out:
# [
#     {
#         'title': 'Associate Dentist',
#         'company': None,
#         'location': None,
#         'salary': '$1,000 a day',
#         'snippet': 'Come join our Dental 360 team, we are looking for a General Dentist with motivation, skills,
# and passion to provide comprehensive dentistry in Chicago &…',
#         'date_posted': '14d',
#         'job_url': '/job/XiGghkup8AkFi4FR1GEYRa0qnXWZO_9FC1XZn3QqcUV00wM5X9bMLw'
#     },
#     {
#         'title': 'Associate Dentist',
#         'company': None,
#         'location': None,
#         'salary': 'From $90 an hour',
#         'snippet': 'Must be licensed in the State of Maine to practice Dentistry. Job Types: Part-time, Contract,
# Temporary.',
#         'date_posted': '5h',
#         'job_url': '/job/dfAg_JB-CuHubrpqv_z11RMSazfZtpwS8ZKH8uU2EVqJNYzh9h_cjw'
#     },
#     {
#         'title': 'Associate Dentist',
#         'company': None,
#         'location': None,
#         'salary': '$750 - $900 a day',
#         'snippet': 'Adhere to all federal and government regulations, including the state dental board rules and
# regulations, HIPPA and OSHA regulations.',
#         'date_posted': '10d',
#         'job_url': '/job/VWK8GkLfirgiKGQrAl6U4YIXF0Rvwg6i0Lns1_TiG6Se3-hMBbQnvQ'
#     },
#     {
#         'title': 'Associate Dentist',
#         'company': None,
#         'location': None,
#         'salary': '$138,215 - $343,695 a year',
#         'snippet': 'All phases of dentistry includes: crown and bridge, molar endodontics, cosmetics, oral surgery
# including molar impactions, periodontics including minor crown…',
#         'date_posted': None,
#         'job_url': '/job/cIsVj3t8bW9jOyVwM9CLvYEW1k712GvZDu6gl96PZltEHNjxYuN7pw'
#     },
#     {
#         'title': 'Associate Dentist',
#         'company': None,
#         'location': None,
#         'salary': '$73,061 - $302,166 a year',
#         'snippet': 'Looking for a general dentist associate for a friendly dental office. Will perform all aspects
# of dentistry. Job Types: Full-time, Part-time, Contract.',
#         'date_posted': '9h',
#         'job_url': '/job/6drjVceN9ooqjdlGscNEy_T2qrbHxa2mjgPE25p0fYK75eIuMOkFWg'
#     },
#     {
#         'title': 'Associate Dentist',
#         'company': None,
#         'location': None,
#         'salary': '$500 a day',
#         'snippet': 'As a Remote Dentist, you will conduct virtual oral health assessments for patients and adhere
# to Medi-Cal clinical guidelines for Synchronize Tele-dentistry.',
#         'date_posted': '5d',
#         'job_url': '/job/WHuv35wzqVVXlt3BbUc3l_0N7CuXJPPcZgXIIkZup4P8CYFrIso0lQ'
#     },
#     {
#         'title': 'Associate Dentist',
#         'company': None,
#         'location': None,
#         'salary': '$800 - $1,500 a day',
#         'snippet': 'Highly organized busy group practice is seeking a qualified dentist with a minimum of 2 years
# experience for full or part time. Job Types: Full-time, Part-time.',
#         'date_posted': '7d',
#         'job_url': '/job/_ajAwCKufSsPaRhLjMD7me9dTGcOWH2dSQbmxXPZ-nkaEE4pQPkn8w'
#     },
#     {
#         'title': 'Associate Dentist',
#         'company': None,
#         'location': None,
#         'salary': '$700 - $950 a day',
#         'snippet': 'We are a private, expanding dental office providing a full-range of high quality, comprehensive
# care.',
#         'date_posted': '13d',
#         'job_url': '/job/6slGepMiIU-gIDkixXZdMxop9NhtuNoNNkT9e_zlxrQGoF6ZjYnAnw'
#     },
#     {
#         'title': 'Associate Dentist',
#         'company': None,
#         'location': None,
#         'salary': 'From $750 a day',
#         'snippet': 'Current license to practice dentistry in the state of NJ. Supervise the work of professional,
# technical and administrative staff.',
#         'date_posted': '3d',
#         'job_url': '/job/ERJebioOTX1jBC8j3cLTZyYqHrkIizFJkLCPW-SNcWWwbCz1zp4rKg'
#     },
#     {
#         'title': 'Associate Dentist',
#         'company': None,
#         'location': None,
#         'salary': 'Up to $4,000 a day',
#         'snippet': 'We are seeking a bilingual( english and spanish) compassionate and highly skilled dentist with
# ample experience in placing and restoring dental implants…',
#         'date_posted': '1d',
#         'job_url': '/job/9AKn1kLGqOMetKeE-gP1m7ODp9aMbANKjfjXlNGGShacI1AEXP7JiQ'
#     },
#     {
#         'title': 'Associate Dentist',
#         'company': None,
#         'location': None,
#         'salary': '$20 - $23 an hour',
#         'snippet': 'Current RDA certification and compliance with state dental board regulations. Strong
# organizational and multitasking skills to handle a busy front desk.',
#         'date_posted': '17h',
#         'job_url': '/job/c3had8QKSJfAjHglmqZrz6IL1ZZo0dFdwZynJlqiutrlzupa-vH8kw'
#     },
#     {
#         'title': 'Associate Dentist',
#         'company': None,
#         'location': None,
#         'salary': '$155,699 - $221,590 a year',
#         'snippet': 'General Dentist Needed for Private Practice in South Orange. We have a great team and great
# patients. If you like helping people, then this is the place for you…',
#         'date_posted': '5d',
#         'job_url': '/job/4ri65Egtt9SOV8PTj33hksPr3lDXoZaGEe1YIl4GLMTYMuSRapT9kw'
#     },
#     {
#         'title': 'Associate Dentist',
#         'company': None,
#         'location': None,
#         'salary': '$120,000 - $250,000 a year',
#         'snippet': 'You may be the candidate we need if you have experience in advanced full mouth rehabilitation
# with crown and bridge and total mouth implant cases and hybrids.',
#         'date_posted': None,
#         'job_url': '/job/v5h3PWY_6VFScJeAxFWhMhWQWZiUizOBUvLar8vqvMyZPopaXtf6mA'
#     },
#     {
#         'title': 'Associate Dentist',
#         'company': None,
#         'location': None,
#         'salary': '$800 - $2,000 a day',
#         'snippet': 'Average take home for experienced dentist is roughly $1200-1400 if you are experienced. Looking
# for confident and motivated General Dentist to come in to our…',
#         'date_posted': None,
#         'job_url': '/job/AX5-Z2G8juvyI-chRbO-f82KBsnYx_6W_Z6E924BnlZVK7BPSOookg'
#     },
#     {
#         'title': 'Associate Dentist',
#         'company': None,
#         'location': None,
#         'salary': '$800 - $2,000 a day',
#         'snippet': 'Looking For General Dentist who is comfortable with seeing Pediatric patients. Job Types:
# Full-time, Part-time.',
#         'date_posted': None,
#         'job_url': '/job/zxj5yq2fkiqdJ7JgsWfm5Dm3nPJxDNAlyZgUDtOlta14WP9meTREsw'
#     },
#     {
#         'title': 'Associate Dentist',
#         'company': None,
#         'location': None,
#         'salary': '$500 - $2,000 a day',
#         'snippet': 'The position is full-time for the right candidate. Experience is preferred (at least 1 year),
# but we are happy to mentor as needed.',
#         'date_posted': None,
#         'job_url': '/job/pQPxKpz1LnIiTov7EPhzDhlNY1IcAb1dVCm3UiQcUOGNJc7_uBR8zA'
#     },
#     {
#         'title': 'Associate Dentist',
#         'company': None,
#         'location': None,
#         'salary': '$1,200 - $1,800 a day',
#         'snippet': 'The position can be both part-time or full-time. Job Types: Full-time, Part-time.',
#         'date_posted': '12d',
#         'job_url': '/job/syXL2pSVgfwHkJjto5j0KH-MluD_Kpt3maOyel4sODteXCW4zaVZWQ'
#     },
#     {
#         'title': 'Associate Dentist',
#         'company': None,
#         'location': None,
#         'salary': '$700 - $1,500 a day',
#         'snippet': 'As an associate, you will examine, diagnose, and provide treatment and counseling to patients
# in a comprehensive manner.',
#         'date_posted': '3d',
#         'job_url': '/job/UsKTD7Qcvmo2kVFUNwkES9gthM8x8uq8J9uuxhiIMLY6a8mhvRYQMA'
#     },
#     {
#         'title': 'Associate Dentist',
#         'company': None,
#         'location': None,
#         'salary': '$500 - $1,500 a day',
#         'snippet': 'No messy insurance preventing you from helping patients. Only two possible treatments for
# patients - no complicated treatment plans.',
#         'date_posted': None,
#         'job_url': '/job/ny5OsRnbFk_CQGYKELtByUb870LtDtH7Gz5fPaRK7wCMqftS9q0oHA'
#     }
# ]
